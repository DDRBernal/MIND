# %%
# Visualisacion

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
#dataframe
df =pd.read_csv('wines.csv', index_col="num")

# %%
df.head()
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# num
# 0              7.4              0.70         0.00             1.9      0.076
# 1              7.8              0.88         0.00             2.6      0.098
# 2              7.8              0.76         0.04             2.3      0.092
# 3             11.2              0.28         0.56             1.9      0.075
# 4              7.4              0.70         0.00             1.9      0.076
#
#      free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# num
# 0                   11.0                  34.0   0.9978  3.51       0.56
# 1                   25.0                  67.0   0.9968  3.20       0.68
# 2                   15.0                  54.0   0.9970  3.26       0.65
# 3                   17.0                  60.0   0.9980  3.16       0.58
# 4                   11.0                  34.0   0.9978  3.51       0.56
#
#      alcohol  quality color
# num
# 0        9.4        5   red
# 1        9.8        5   red
# 2        9.8        5   red
# 3        9.8        6   red
# 4        9.4        5   red

# %%
df.color= pd.Categorical(df.color)

# %%
df.dtypes
# Out:
# fixed acidity            float64
# volatile acidity         float64
# citric acid              float64
# residual sugar           float64
# chlorides                float64
# free sulfur dioxide      float64
# total sulfur dioxide     float64
# density                  float64
# pH                       float64
# sulphates                float64
# alcohol                  float64
# quality                    int64
# color                   category
# dtype: object

# %%
#nombres columnas df.columns
df.columns=df.columns.str.replace(" ","_")

# %%
#se crea una nueva columna, y cambiar los valores de los colores por un numero
df['color_cod'] = df.color.cat.codes

# %%
df.head()
# Out:
#      fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# num
# 0              7.4              0.70         0.00             1.9      0.076
# 1              7.8              0.88         0.00             2.6      0.098
# 2              7.8              0.76         0.04             2.3      0.092
# 3             11.2              0.28         0.56             1.9      0.075
# 4              7.4              0.70         0.00             1.9      0.076
#
#      free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# num
# 0                   11.0                  34.0   0.9978  3.51       0.56
# 1                   25.0                  67.0   0.9968  3.20       0.68
# 2                   15.0                  54.0   0.9970  3.26       0.65
# 3                   17.0                  60.0   0.9980  3.16       0.58
# 4                   11.0                  34.0   0.9978  3.51       0.56
#
#      alcohol  quality color  color_cod
# num
# 0        9.4        5   red          0
# 1        9.8        5   red          0
# 2        9.8        5   red          0
# 3        9.8        6   red          0
# 4        9.4        5   red          0

# %%
#Diagrama de dispersion, con una columna x e y
#Dispersion
df.plot.scatter(x = 'fixed_acidity', y = 'volatile_acidity')

# %%
df.plot.scatter(x = 'fixed_acidity', y = 'volatile_acidity',c="black")

# %%
# google matplotlib colormap
df.plot.scatter(x = 'fixed_acidity', y = 'volatile_acidity',c="color_cod",colormap='Paired')
# para grabar
plt.savefig("scatter1.png")

# %%
#
df.plot.hexbin(x="fixed_acidity",y="volatile_acidity",gridsize=20, colormap="magma")

# %%
#histogramas
df.hist(column = "density", bins = 5, grid=False,color="Red")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000212E18FB320>]],
#       dtype=object)

# %%
df.hist(column = "density", bins = 5, grid=False,color="#F7BEB1", by="color")
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x00000212E2059208>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000212E20B8390>],
#       dtype=object)

# %%
df[['citric_acid','chlorides','density']].plot.hist(bins=10, alpha=0.5)

# %%
df.describe()
# Out:
#        fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# count    6497.000000       6497.000000  6497.000000     6497.000000
# mean        7.215307          0.339666     0.318633        5.443235
# std         1.296434          0.164636     0.145318        4.757804
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free_sulfur_dioxide  total_sulfur_dioxide      density  \
# count  6497.000000          6497.000000           6497.000000  6497.000000
# mean      0.056034            30.525319            115.744574     0.994697
# std       0.035034            17.749400             56.521855     0.002999
# min       0.009000             1.000000              6.000000     0.987110
# 25%       0.038000            17.000000             77.000000     0.992340
# 50%       0.047000            29.000000            118.000000     0.994890
# 75%       0.065000            41.000000            156.000000     0.996990
# max       0.611000           289.000000            440.000000     1.038980
#
#                 pH    sulphates      alcohol      quality    color_cod
# count  6497.000000  6497.000000  6497.000000  6497.000000  6497.000000
# mean      3.218501     0.531268    10.491801     5.818378     0.753886
# std       0.160787     0.148806     1.192712     0.873255     0.430779
# min       2.720000     0.220000     8.000000     3.000000     0.000000
# 25%       3.110000     0.430000     9.500000     5.000000     1.000000
# 50%       3.210000     0.510000    10.300000     6.000000     1.000000
# 75%       3.320000     0.600000    11.300000     6.000000     1.000000
# max       4.010000     2.000000    14.900000     9.000000     1.000000

# %%
df.boxplot(column=['residual_sugar','pH'],by='color',vert=False)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x00000212E3FC5550>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000212E403B0F0>],
#       dtype=object)

# %%
df.boxplot(column='total_sulfur_dioxide',by='color',vert=False)
